# %%
import pandas as pd

# %%
url = 'https://github.com/ianCristianAriel/2024_asistente_compras/blob/main/DatosPreciosSupermercado/preciosCarrefour.csv'

# %%
#me da error

df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b968eff41582> in <cell line: 1>()
# ----> 1 df = pd.read_csv(url, error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %% [markdown]
# PRECIOS CARREFOUR

# %%
df = pd.read_csv('/content/drive/MyDrive/ISPC/3ero/preciosCarrefour.csv', sep=';')

# %%
df.head()
# Out:
#   Categoria                                           Producto      Precio  \
# 0   almacen  Lomitos de atún Carrefour classic al natural 1...  $ 1.791,00
# 1   almacen            Puré de tomate Carrefour classic 520 g.  $ 1.990,00
# 2   almacen                             Mayonesa Natura 475 g.    $ 699,00
# 3   almacen  Aceite de girasol Carrefour alto omega pet 900...  $ 1.280,00
# 4   almacen                    Sal fina Celusal paquete 500 g.  $ 1.395,00
#
#                                     URL de la imagen            Fecha_hora
# 0  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46
# 1  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46
# 2  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46
# 3  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46
# 4  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46

# %%
#Se buscan valores vacios
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3336 entries, 0 to 3335
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Categoria         3336 non-null   object
#  1   Producto          3336 non-null   object
#  2   Precio            3336 non-null   object
#  3   URL de la imagen  3336 non-null   object
#  4   Fecha_hora        3336 non-null   object
# dtypes: object(5)
# memory usage: 130.4+ KB

# %%
#Se buscan duplicados

duplicados = df[df.duplicated()]
print(duplicados)
# Out:
# Empty DataFrame
# Columns: [Categoria, Producto, Precio, URL de la imagen, Fecha_hora]
# Index: []

# %%
duplicados = df[df.duplicated(subset=['Producto'])]
print(duplicados)
# Out:
#        Categoria                                           Producto  \
# 7        almacen  Lomitos de atún Carrefour classic al natural 1...
# 8        almacen            Puré de tomate Carrefour classic 520 g.
# 9        almacen                             Mayonesa Natura 475 g.
# 10       almacen  Aceite de girasol Carrefour alto omega pet 900...
# 11       almacen                    Sal fina Celusal paquete 500 g.
# ...          ...                                                ...
# 3331  perfumeria  Antitranspirante en aerosol Dove original 150 cc.
# 3332  perfumeria  Jabón de tocador Lux rosas francesas 125 g. x ...
# 3333  perfumeria          Shampoo Dove regeneración extrema 400 cc.
# 3334  perfumeria                Shampoo Dove óleo nutrición 400 cc.
# 3335  perfumeria          Jabón de tocador Dove leche de coco 90 g.
#
#           Precio                                   URL de la imagen  \
# 7     $ 1.791,00  https://carrefourar.vtexassets.com/arquivos/id...
# ...

# %%
df_sin_duplicados = df.drop_duplicates(subset=['Producto'])

# %%
df_sin_duplicados.head()
# Out:
#   Categoria                                           Producto      Precio  \
# 0   almacen  Lomitos de atún Carrefour classic al natural 1...  $ 1.791,00
# 1   almacen            Puré de tomate Carrefour classic 520 g.  $ 1.990,00
# 2   almacen                             Mayonesa Natura 475 g.    $ 699,00
# 3   almacen  Aceite de girasol Carrefour alto omega pet 900...  $ 1.280,00
# 4   almacen                    Sal fina Celusal paquete 500 g.  $ 1.395,00
#
#                                     URL de la imagen            Fecha_hora
# 0  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46
# 1  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46
# 2  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46
# 3  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46
# 4  https://carrefourar.vtexassets.com/arquivos/id...  09/05/2024, 16:33:46

# %%
df_sin_duplicados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 0 to 2947
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Categoria         108 non-null    object
#  1   Producto          108 non-null    object
#  2   Precio            108 non-null    object
#  3   URL de la imagen  108 non-null    object
#  4   Fecha_hora        108 non-null    object
# dtypes: object(5)
# memory usage: 9.1+ KB

# %%
df_sin_duplicados.to_csv('preciosCarrefourok.csv', index=False)

# %% [markdown]
# PRECIOS JUMBO

# %%
url = 'https://github.com/ianCristianAriel/2024_asistente_compras/blob/main/DatosPreciosSupermercado/preciosJumbo.csv'

# %%
df = pd.read_csv('/content/drive/MyDrive/ISPC/3ero/preciosJumbo(1).csv', sep=';')

# %%
df.head()
# Out:
#   Categoria                                           Producto Precio  \
# 0   Almacen                    Yerba Mate Playadito Suave 1 Kg    NaN
# 1   Almacen  Galletitas Pepitos Con Chips De Chocolate 357g...    NaN
# 2   Almacen                     Aceite De Girasol Natura 1.5 L    NaN
# 3   Almacen               Atun Al Natural La Campagnola 170 Gr    NaN
# 4   Almacen               Yerba Mate De Campo La Merced 500 Gr    NaN
#
#                                     URL de la imagen            fecha_hora
# 0  https://jumboargentinaio.vtexassets.com/arquiv...  09/05/2024, 14:35:08
# 1  https://jumboargentinaio.vtexassets.com/arquiv...  09/05/2024, 14:35:08
# 2  https://jumboargentinaio.vtexassets.com/arquiv...  09/05/2024, 14:35:08
# 3  https://jumboargentinaio.vtexassets.com/arquiv...  09/05/2024, 14:35:08
# 4  https://jumboargentinaio.vtexassets.com/arquiv...  09/05/2024, 14:35:08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2144 entries, 0 to 2143
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Categoria         2144 non-null   object
#  1   Producto          2144 non-null   object
#  2   Precio            1128 non-null   object
#  3   URL de la imagen  2144 non-null   object
#  4   fecha_hora        2144 non-null   object
# dtypes: object(5)
# memory usage: 83.9+ KB

# %%
duplicados = df[df.duplicated(subset=['Producto'])]
print(duplicados)
# Out:
#        Categoria                                           Producto  \
# 8        Almacen                    Yerba Mate Playadito Suave 1 Kg
# 9        Almacen  Galletitas Pepitos Con Chips De Chocolate 357g...
# 10       Almacen                     Aceite De Girasol Natura 1.5 L
# 11       Almacen               Atun Al Natural La Campagnola 170 Gr
# 12       Almacen               Yerba Mate De Campo La Merced 500 Gr
# ...          ...                                                ...
# 2139  perfumeria                 Shampoo Dove Reconstrucción 400 Ml
# 2140  perfumeria  Pasta Dental Colgate Sensitive Pro Alivio Inme...
# 2141  perfumeria  Acondicionador Dove Reconstrucción Completa 40...
# 2142  perfumeria      Shampoo Dove Ritual De Reparación Coco 750 Ml
# 2143  perfumeria               Desodorante Dove Invisible Dry 150ml
#
#          Precio                                   URL de la imagen  \
# 8        $4.759  https://jumboargentinaio.vtexassets.com/arquiv...
# ...

# %%
df_sin_duplicados = df.drop_duplicates(subset=['Producto'])

# %%
df_sin_duplicados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76 entries, 0 to 1751
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Categoria         76 non-null     object
#  1   Producto          76 non-null     object
#  2   Precio            40 non-null     object
#  3   URL de la imagen  76 non-null     object
#  4   fecha_hora        76 non-null     object
# dtypes: object(5)
# memory usage: 3.6+ KB

# %%
df_sin_duplicados.to_csv('preciosJumbook.csv', index=False)

# %%
df_sin_duplicados = df_sin_duplicados.dropna(subset=['Precio'])

# %%
df_sin_duplicados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 16 to 1583
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Categoria         40 non-null     object
#  1   Producto          40 non-null     object
#  2   Precio            40 non-null     object
#  3   URL de la imagen  40 non-null     object
#  4   fecha_hora        40 non-null     object
# dtypes: object(5)
# memory usage: 1.9+ KB

# %%
df_sin_duplicados.to_csv('Jumbo_sin_duplicados_sin_vacios.csv', index=False)

# %% [markdown]
# La Anonima

# %%
url = 'https://github.com/ianCristianAriel/2024_asistente_compras/blob/main/DatosPreciosSupermercado/preciosLaAnonima.csv'

# %%
df = pd.read_csv('/content/drive/MyDrive/ISPC/3ero/preciosLaAnonima.csv', sep=';')

# %%
df.head()
# Out:
#   Categoria            Fecha_hora  \
# 0   almacen  09/05/2024, 12:46:22
# 1   almacen  09/05/2024, 12:46:22
# 2   almacen  09/05/2024, 12:46:22
# 3   almacen  09/05/2024, 12:46:22
# 4   almacen  09/05/2024, 12:46:22
#
#                                             Producto      Precio  \
# 0  Pizza con Mozzarella y Jamón sin Tacc Keila x ...  $ 6.550,00
# 1     Atún al Natural en Lomitos La Anónima x 160 g.  $ 4.912,50
# 2      Galletitas con chips x 3 Un. Pepitos x 357 g.   $2.600,00
# 3           Yerba Mate c/Palo 4Flex Mañanita x 1 Kg.  $ 1.749,00
# 4   Azúcar Blanco Refinado Superior  Ledesma x 1 Kg.   $3.800,00
#
#                                     URL de la imagen
# 0  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...
# 1  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...
# 2  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...
# 3  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...
# 4  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...

# %%
df = df[['Categoria', 'Producto', 'Precio', 'URL de la imagen', 'Fecha_hora']]

# %%
df.head()
# Out:
#   Categoria                                           Producto      Precio  \
# 0   almacen  Pizza con Mozzarella y Jamón sin Tacc Keila x ...  $ 6.550,00
# 1   almacen     Atún al Natural en Lomitos La Anónima x 160 g.  $ 4.912,50
# 2   almacen      Galletitas con chips x 3 Un. Pepitos x 357 g.   $2.600,00
# 3   almacen           Yerba Mate c/Palo 4Flex Mañanita x 1 Kg.  $ 1.749,00
# 4   almacen   Azúcar Blanco Refinado Superior  Ledesma x 1 Kg.   $3.800,00
#
#                                     URL de la imagen            Fecha_hora
# 0  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22
# 1  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22
# 2  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22
# 3  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22
# 4  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10744 entries, 0 to 10743
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Categoria         10744 non-null  object
#  1   Producto          10744 non-null  object
#  2   Precio            10744 non-null  object
#  3   URL de la imagen  10744 non-null  object
#  4   Fecha_hora        10744 non-null  object
# dtypes: object(5)
# memory usage: 419.8+ KB

# %%
duplicados = df[df.duplicated(subset=['Producto'])]
print(duplicados)
# Out:
#          Categoria                                           Producto  \
# 110        almacen    Café Instantáneo Original Nescafé Dolca x 170g.
# 205        almacen                  Fideos Fusilli Lucchetti x 500 g.
# 766        frescos        Crema de Leche L.V. La Serenísima x 200 cc.
# 1114       almacen  Pizza con Mozzarella y Jamón sin Tacc Keila x ...
# 1115       almacen     Atún al Natural en Lomitos La Anónima x 160 g.
# ...            ...                                                ...
# 10739  vinos-finos          Vino Sauvignon Blanc Goyenechea x 750 cc.
# 10740  vinos-finos              Vino Tinto Blend Contracara x 750 cc.
# 10741  vinos-finos           Vino Tinto Red Blend Esmeralda x 750 cc.
# 10742  vinos-finos             Vino Tinto Malbec Contracara x 750 cc.
# 10743  vinos-finos                 Vino Tinto Omnium Malbec x 750 cc.
#
#            Precio                                   URL de la imagen  \
# ...

# %%
df_sin_duplicados = df.drop_duplicates(subset=['Producto'])

# %%
df_sin_duplicados.head()
# Out:
#   Categoria                                           Producto      Precio  \
# 0   almacen  Pizza con Mozzarella y Jamón sin Tacc Keila x ...  $ 6.550,00
# 1   almacen     Atún al Natural en Lomitos La Anónima x 160 g.  $ 4.912,50
# 2   almacen      Galletitas con chips x 3 Un. Pepitos x 357 g.   $2.600,00
# 3   almacen           Yerba Mate c/Palo 4Flex Mañanita x 1 Kg.  $ 1.749,00
# 4   almacen   Azúcar Blanco Refinado Superior  Ledesma x 1 Kg.   $3.800,00
#
#                                     URL de la imagen            Fecha_hora
# 0  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22
# 1  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22
# 2  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22
# 3  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22
# 4  https://d1on8qs0xdu5jz.cloudfront.net/web/imag...  09/05/2024, 12:46:22

# %%
df_sin_duplicados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9173 entries, 0 to 10313
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Categoria         9173 non-null   object
#  1   Producto          9173 non-null   object
#  2   Precio            9173 non-null   object
#  3   URL de la imagen  9173 non-null   object
#  4   Fecha_hora        9173 non-null   object
# dtypes: object(5)
# memory usage: 688.0+ KB

# %%
df_sin_duplicados.to_csv('anonimaok.csv', index=False)
